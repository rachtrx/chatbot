# %%
import datetime
import os
import requests
from dotenv import load_dotenv
import docx
import sys, pathlib, fitz
import io
import math

# To analyze the PDF layout and extract text
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure
# To extract text from tables in PDF
import pdfplumber
# To extract the images from the PDFs
from PIL import Image
# To perform OCR to extract text from images 
import pytesseract 
import pandas as pd

load_dotenv("../.env")

config = {
    'client_id': os.environ.get('CLIENT_ID'),
    'client_secret': os.environ.get('CLIENT_SECRET'),
    'authority': os.environ.get('AUTHORITY'),
    'scope': [os.environ.get('SCOPE')],
    'site_id': os.environ.get('SITE_ID'),
}

headers = {
        'Authorization': f'Bearer {os.environ.get("ACCESS_TOKEN")}',
        'Content-Type': 'application/json'
    }



drive_url = f"https://graph.microsoft.com/v1.0/drives/{os.environ.get('DRIVE_ID')}"

# %%
def extract_table(pdf_path, page_num, table_num):
    # Open the pdf file
    pdf = pdfplumber.open(pdf_path)
    # Find the examined page
    table_page = pdf.pages[page_num]
    # Extract the appropriate table
    table = table_page.extract_tables()[table_num]
    return table

# Convert table into the appropriate format
def table_converter(table):
    table_string = ''
    # Iterate through each row of the table
    for row_num in range(len(table)):
        row = table[row_num]
        # Remove the line breaker from the wrapped texts
        cleaned_row = [item.replace('\n', ' ') if item is not None and '\n' in item else 'None' if item is None else item for item in row]
        # Convert the table into a string 
        table_string+=('|'+'|'.join(cleaned_row)+'|'+'\n')
    # Removing the last line break
    table_string = table_string[:-1]
    return table_string

def crop_image_to_text(element, page):
    # Get the coordinates to crop the image from the PDF
    [x0, y0, x1, y1] = [element.x0, element.y0, element.x1, element.y1]

    # Define the rectangle to crop
    clip_rect = fitz.Rect(x0, y0, x1, y1)

    # Crop the page to the size of the image
    pix = page.get_pixmap(clip=clip_rect)

    # Convert the pixmap to an image
    img_data = pix.tobytes("png")  # Convert the image to PNG bytes
    img = Image.open(io.BytesIO(img_data))
    text = pytesseract.image_to_string(img)
    return text

def is_bold(font_name):
    return "Bold" in font_name or "Bd" in font_name

def process_text_element(element):

    line_text = ""
    current_word = ""
    sum_words_font_size = 0
    word_count = 0
    current_word_bold = False

    # if isinstance(element, LTTextContainer):
    #     # Iterating through each character in the line of text
    for text_line in element:
        if isinstance(text_line, LTTextContainer):  # Check if it's a text line
            for character in text_line:
                if isinstance(character, LTChar):
                    current_word += character.get_text()
            
                    # Check for bold
                    if is_bold(character.fontname):
                        current_word_bold = True

                    # Store font size
                    current_font_size = round(character.size)

                if character.get_text().isspace():
                    # Space encountered, word ends
                    if current_word:
                        word_count += 1
                        sum_words_font_size += current_font_size
                        yield [current_word, current_font_size, current_word_bold]
                    
                    # Reset for next word
                    current_word = ""
                    current_font_size = []
                    current_word_bold = False

    return [sum_words_font_size, word_count]

def read_pdf(stream):

    # Create the dictionary to extract text from each image
    # text_per_page = {}

    doc = fitz.open(stream=stream, filetype="pdf")

    # Open the pdf file
    pdf_stream = io.BytesIO(stream)
    pdf = pdfplumber.open(pdf_stream)

    doc_content = []

    words_info = []
    sum_words_font_size = 0
    word_count = 0
    
    # We extract the pages from the PDF
    for pagenum, page in enumerate(extract_pages(pdf_stream)):
        
        # Initialize the variables needed for the text extraction from the page
        fitz_page = doc.load_page(pagenum)

        table_num = 0
        first_element= True
        table_extraction_flag= False
        
        # Find the examined page
        page_tables = pdf.pages[pagenum]
        # Find the number of tables on the page
        tables = page_tables.find_tables()


        # Find all the elements
        page_elements = [(element.y1, element) for element in page._objs]
        # Sort all the elements as they appear in the page 
        page_elements.sort(key=lambda a: a[0], reverse=True)

        lower_side = upper_side = None

        # Find the elements that composed a page
        for i, component in enumerate(page_elements):
            # Extract the element of the page layout
            element = component[1]
            
            # Check if the element is a text element

            if isinstance(element, LTTextContainer):
                # Check if the text appeared in a table
                if table_extraction_flag == False:
                    # Use the function to extract the text and format for each text element
                    generator = process_text_element(element)

                    try:
                        while True:
                            # Process each yielded value
                            word_info = next(generator)
                            # Do something with word_info
                            doc_content.append(word_info[0])
                            words_info.append(word_info)
                    except StopIteration as e:
                        # Catch the return value from the generator
                        sum_words_font_size += e.value[0]
                        word_count += e.value[1]

                else:
                    # Omit the text that appeared in a table
                    pass

            # Check the elements for images
            if isinstance(element, LTFigure):
                # Crop the image from the PDF
                image_text = crop_image_to_text(element, fitz_page)
                # text_from_images.append(image_text)
                doc_content.append(image_text)

            # Check the elements for tables
            if isinstance(element, LTRect):
                # If the first rectangular element
                if first_element == True and (table_num + 1) <= len(tables):
                    # Find the bounding box of the table
                    lower_side = page.bbox[3] - tables[table_num].bbox[3]
                    upper_side = element.y1 
                    # Extract the information from the table
                    table = extract_table(pdf_stream, pagenum, table_num)
                    # Convert the table information in structured string format
                    table_string = table_converter(table)
                    # Append the table string into a list
                    # text_from_tables.append(table_string)
                    doc_content.append(table_string)
                    # Set the flag as True to avoid the content again
                    table_extraction_flag = True
                    # Make it another element
                    first_element = False

                # Check if we already extracted the tables from the page
                if lower_side and upper_side and element.y0 >= lower_side and element.y1 <= upper_side:
                    pass
                elif i + 1 < len(page_elements) and not isinstance(page_elements[i+1][1], LTRect):
                    table_extraction_flag = False
                    first_element = True
                    table_num += 1

    # Closing the pdf file object
    doc.close()

    text = ''.join(doc_content)

    avg_font_size = sum_words_font_size / word_count

    print(words_info)

    words_df = pd.DataFrame(data = words_info, columns = ["word", "font_size", "bold"])

    # return words_df
    return [text, words_df]

# %%
def loop_through_files(url, fileobj=None):


    response = requests.get(url=url, headers=headers)
    # response.raise_for_status()
    if not 200 <= response.status_code < 300:
        print("something went wrong when getting files")
        return

    if fileobj:
        filename = fileobj["name"]
        data = read_pdf(response.content)
        text = data[0]
        print(text)
        words_df = data[1]
        print(filename)
        return words_df
    
    for value in response.json()['value']:

        new_fileobj = None
        if value['name'].endswith(".pdf"):
            new_fileobj = value
            new_url = value['@microsoft.graph.downloadUrl']
            return loop_through_files(new_url, new_fileobj)
        elif value.get('folder'):
            new_url = url[:-len(':/children')] + '/' + value['name'] + ':/children'
            loop_through_files(new_url, new_fileobj)
            return loop_through_files(new_url, new_fileobj)
        else:
            continue

# %%
temp_url = os.environ.get('TEMP_FOLDER_URL')

words_df = loop_through_files(temp_url)
# Out:
# [['REF: ', 11, False], ['2023/PRI/01/01 ', 11, False], [' ', 11, False], ['6 ', 11, False], ['January ', 11, False], ['2023 ', 11, False], ['Dear ', 11, False], ['Parents/Guardians, ', 11, False], ['Welcome ', 11, False], ['to ', 11, False], ['the ', 11, False], ['start ', 11, False], ['of ', 11, False], ['another ', 11, False], ['new ', 11, False], ['school ', 11, False], ['year! ', 11, False], [' ', 11, False], ['2023 ', 11, False], ['looks ', 11, False], ['to ', 11, False], ['be ', 11, False], ['an ', 11, False], ['exciting ', 11, False], ['one ', 11, False], ['as ', 11, False], ['we ', 11, False], ['resume ', 11, False], ['many ', 11, False], ['programmes ', 11, False], ['and ', 11, False], ['activities ', 11, False], ['that ', 11, False], ['had ', 11, False], ['to ', 11, False], ['be ', 11, False], ['halted ', 11, False], ['or ', 11, False], ['modified ', 11, False], ['due ', 11, False], ['to ', 11, False], ['COVID. ', 11, False], ['There ', 11, False], ['are ', 11, False], ['a ', 11, False], ['few ', 11, False], ['initiatives ', 11, False], ['we ', 11, False], ['have ', 11, False], ['been ', 11, False], ['strengthening ', 11, False], ['and ', 11, False], ['working ', 11, False], ['on ', 11, False], ['as ', 11, False], ['we ', 11, False], ['move ', 11, False], ['towards ', 11, False], ['our ', 11, False], ['vision ', 11, False], ['of ', 11, False], ['‘A ', 11, False], ['Vibrant ', 11, False], ['School ', 11, False], ['Community ', 11, False], ['where ', 11, False], ['Education ', 11, False], ['is ', 11, False], ['Transformed’. ', 11, False], ['I ', 11, False], ['look ', 11, False], ['forward ', 11, False], ['to ', 11, False], ['sharing ', 11, False], ['these ', 11, False], ['with ', 11, False], ['you ', 11, False], ['at ', 11, False], ['our ', 11, False], ['first ', 11, False], ['Parent-Teacher ', 11, False], ['Conference ', 11, False], ['on ', 11, False], ['3rd ', 11, False], ['February. ', 11, False], [' ', 11, False], [' ', 11, False], ['As ', 11, False], ['per ', 11, False], ['previous ', 11, False], ['years, ', 11, False], ['this ', 11, False], ['monthly ', 11, False], ['letter ', 11, False], ['contains ', 11, False], ['pertinent ', 11, False], ['information ', 11, False], ['that ', 11, False], ['we ', 11, False], ['hope ', 11, False], ['will ', 11, False], ['be ', 11, False], ['useful ', 11, False], ['in ', 11, False], ['navigating ', 11, False], ['the ', 11, False], ['school ', 11, False], ['year. ', 11, False], ['I ', 11, False], ['encourage ', 11, False], ['you ', 11, False], ['to ', 11, False], ['take ', 11, False], ['the ', 11, False], ['time ', 11, False], ['to ', 11, False], ['read ', 11, False], ['through ', 11, False], ['the ', 11, False], ['information ', 11, False], ['provided ', 11, False], ['in ', 11, False], ['these ', 11, False], ['letters. ', 11, False], [' ', 11, False], ['My ', 11, False], ['staff ', 11, False], ['and ', 11, False], ['I ', 11, False], ['look ', 11, False], ['forward ', 11, False], ['to ', 11, False], ['your ', 11, False], ['continued ', 11, False], ['partnership ', 11, False], ['in ', 11, False], ['our ', 11, False], ['desire ', 11, False], ['to ', 11, False], ['have ', 11, False], ['our ', 11, False], ['students ', 11, False], ['‘rooted ', 11, False], ['in ', 11, False], ['values, ', 11, False], ['prepared ', 11, False], ['for ', 11, False], ['life, ', 11, False], ['and ', 11, False], ['empowered ', 11, False], ['to ', 11, False], ['make ', 11, False], ['a ', 11, False], ['difference’. ', 11, False], [' ', 11, False], ['FOR ', 11, True], ['YOUR ', 11, True], ['ACTION ', 11, True], ['1) ', 11, False], ['Sale ', 11, True], ['of ', 11, True], ['Uniform ', 11, True], ['in ', 11, True], ['School ', 11, True], ['The ', 11, False], ['school ', 11, False], ['uniform ', 11, False], ['supplier ', 11, False], ['(Jeep ', 11, False], ['Sing ', 11, False], ['Fashion) ', 11, False], ['will ', 11, False], ['be ', 11, False], ['selling ', 11, False], ['the ', 11, False], ['school ', 11, False], [' ...
# ||Date|||Monday, 9 January 2023||
# ||Time|||10.30 a.m. – 12.15 p.m. & 12.45 p.m. – 1.30 p.m.||
# ||Venue|||In front of the school bookshop||
# |Note|Note|None||When out-of-stock occurs, the uniform vendor will contact parents directly for collection when||
# |None|None|None|None|the stock arrives. The School will not issue the uniforms to your child, including students on the|None|
# |None|None|None|None|Financial Assistance Scheme.|None|REF: 2023/PRI/01/01  6 January 2023 Dear Parents/Guardians, Welcome to the start of another new school year!  2023 looks to be an exciting one as we resume many programmes and activities that had to be halted or modified due to COVID. There are a few initiatives we have been strengthening and working on as we move towards our vision of ‘A Vibrant School Community where Education is Transformed’. I look forward to sharing these with you at our first Parent-Teacher Conference on 3rd February.   As per previous years, this monthly letter contains pertinent information that we hope will be useful in navigating the school year. I encourage you to take the time to read through the information provided in these letters.  My staff and I look forward to your continued partnership in our desire to have our students ‘rooted in values, prepared for life, and empowered to make a difference’.  FOR YOUR ACTION 1) Sale of Uniform in School The school uniform supplier (Jeep Sing Fashion) will be selling the school uniform in front of the school bookshop: Date  Time Venue Note When out-of-stock occurs, the uniform vendor will contact parents directly for collection when the stock arrives. The School will not issue the uniforms to your child, including students on the Financial Assistance Scheme. Monday, 9 January 2023 10.30 a.m. – 12.15 p.m. & 12.45 p.m. – 1.30 p.m. In front of the school bookshop As part of school safety and security, caregivers entering the school will need to register with the security officer at the school main entrance.  2) Temperature-Taking Exercise The school will be conducting a temperature-taking exercise on Wednesday, 11 January 2023, as part of the Safe Management Measures. All students MUST bring their digital thermometer to school on that day. Students may purchase the digital thermometer at $3.50 and/or a battery at $0.20 at the General Office/school bookshop.  3) 2023 Book List  The 2023 Book List will be issued on Monday, 9 Jaunuary. The class teacher will indicate on the list the required learning materials to be purchased for your child/ward. Please pay the exact amount for the materials to your child/ward’s class teacher by Friday, 13 January. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-1 T: 6561 9128     4) School Fees Schedule 2023 The 1st quarter school fees (Jan to March) will be scheduled between 13 and 17 March 2023. You are strongly encouraged to pay your child’s school fees via GIRO/Edusave (please note that a portion of the school fees of $6.50 cannot be deducted from Edusave and will have to be paid via GIRO or in cash). For parents/guardians who have NOT opted for GIRO deduction or whose applications are unsuccessful, school fees are to be paid to the General Office via cash/cheque (payable to Grace Orchard School A/C 2).  Please refer to the Student Diary page 15 on the school fees schedule and amount for the respective programme. In the event that a student withdraws from school before the month, school fees for the month must still be paid in full.  UPCOMING SCHOOL PROGRAMME / ACTIVITIES 5) 20 January, Friday – Chinese New Year Celebration The school will be celebrating Chinese New Year on Friday, 20 January 2023. As part of the celebrations, we encourage all students to dress in red or in traditional Chinese New Year attire (e.g. Cheongsam / Tang Suit). As it is not the eve of Chinese New Year, there will be NO changes to the school reporting and dismissal time on that day. 6) 1 February, Wednesday – Prefects' Investiture   The Prefects’ Investiture will be held on 1 February, 1.00 p.m. – 1.30 p.m.  The investiture is the platform to recognise our prefects for their contribution and dedication in serving the school and community. Parents of the prefects will be invited to witness the ceremony. 7) 3 February, Friday – Parent-Teacher Conference 1 (HBL ...
# ||School Mainline||+65 6561 9128|
# |WhatsApp / SMS|WhatsApp / SMS|None|Please note that the teachers are not obligated to give parents their contact number. If given, it would be a mutual arrangement between parents and teachers. For emergency matters during curriculum time, please contact the School's mainline as the teachers are having lessons and may not be able to respond promptly.|9) Communication with Teachers Parents may communicate with teachers via the following ways: ||Session|||Reporting Time|||Dismissal Time||
# |PM Session|None|None|12.15 pm|None|None|5.30 pm|None|None|
# ||Daily Dismissal Procedures|None|None|None|None|None|None||
# |By School Bus|None|None|• Students taking school transport will be dismissed at the bus bay at 5.30 p.m.|None|None|None|None|None|
# |By Car|None|None|• Parents can drive in and fetch their children at the bus bay from 5.30 p.m. [after the last school bus has left the school carpark] • No cars are allowed to park or wait in the school car park before the dismissal hours.|None|None|None|None|None|
# |By Caregivers / Independent Travellers|None|None|• Students who are fetched by parents or are independent travellers will be dismissed at 5.30 p.m. Caregivers are to wait for their children at the covered walkway next to Side Gate C.|None|None|None|None|None|The School will close at 6.30 p.m. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-3 T: 6561 9128     |CCAs are during curriculum hours and the programmes will commence on T1W6.|
# |Modular CCAs|12) School Safety and Security  The security of the school is crucial in providing a safe environment for the education of our students. We seek your understanding and cooperation in complying with the Road Safety and Visitor Management Policies. A. No Parking in the School Carpark i. Only the school staff and visitors with scheduled appointments can park in the school carpark. ii. Drive-in is allowed during the school arrival and dismissal time for drop-off and pick-up only. The engine of all parked vehicles must be turned off according to the Environmental Protection and Management (vehicular-emissions) Regulations. Failure to comply may lead to a report to the NEA for further actions. |Modular CCA|Venue|Objectives|Classes Involved|
# |Swimming|Clementi Swimming Complex|To provide students with the knowledge and skills for water safety as well as basic swimming competencies|Primary 3 Classes Love 4 and Love 5 (Semester 1 only)|
# |Gym|In School|To enhance the physical development of the students, developing skills such as strength, flexibility, coordination, balance, and body control|Junior Classes Love 6 – 11|CCA Try-outs  Upper Primary and Love 12 students will be placed in a CCA based on their strengths and interest. Students who do not have a CCA will take part in a CCA try-out on Friday, 27 January. |None|enhance the physical development of the|
# |students, developing skills such as strength,|None|
# |flexibility, coordination, balance, and body|None|
# |control|None|14) Health and Fitness Programme The objective of the school’s Health and Fitness programme is to help students to build healthy habits and exercise regularly. To aid your child in this programme, a Health and Fitness booklet will be distributed each semester.  In line with our school’s SWPBS system, students will get to earn hero chops by showing responsibility for their own health and completing the exercises. Do encourage your child/ward to do the exercises daily. |Upper Primary and Love 12 students will be placed in a CCA based on their strengths and interest. Students|
# |who do not have a CCA will take part in a CCA try-out on Friday, 27 January.|
# ||Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-4 T: 6561 9128     |Name of Insurer|None|Chubb Insurance Singapore Limited|None|
# |Medical expenses limit|None|$7,500 per student (Note: Medical expenses limit for registered Chinese physician – $150 per student)|None|
# |Accident death & permanent disablement benefits|None|$25,000 per student|None|
# ||20% co-payment requirement for parents on each medical expenses claim submitted (i.e. the insurer|None||
# |None|will reimburse only up to 80% of all approved medical expenses incurred.)|None|None|15) Student Group Personal Accident Insurance Policy ours Sincerely,
#
# oi
#
# fs Esther Kwan
# rincipal
#
#
# All students of Grace Orchard School are covered under the Student Group Personal Accident Insurance Policy. The insurance can help parents cover some medical expenses that may be incurred if their children are injured while participating in school activities.  Listed below are the revised benefits and terms in the Student Group Personal Accident Insurance Policy currently in force – for your necessary attention: |$7,500 per student (Note: Medical expenses limit for|
# |registered Chinese physician – $150 per student)|$7,500 per student (Note: Medical expenses limit for registered Chinese physician – $150 per student) Medical expenses limit $25,000 per student Accident death & permanent disablement benefits 20% co-payment requirement for parents on each medical expenses claim submitted (i.e. the insurer will reimburse only up to 80% of all approved medical expenses incurred.) The medical expenses claim form is available from the General Office. The claim form with the original medical receipts must be submitted to School within 14 days from the date of the accident. If you have any further query about the above insurance policy, please contact the school Admin Executive at 6561 9128 ext.108 or info@go.edu.sg (via email). Yours Sincerely, Ms Esther Kwan Principal Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-5 T: 6561 9128     ||DATE|||EVENT / ACTIVITY|||REMARKS|None||
# |Monday, 9 January|None|None|Sale of School Uniform|Sale of School Uniform|None|10.30 am – 12.15 pm & 12.45 pm – 1.30 pm|None|None|None|
# |Friday, 13 January|None|None|Payment (exact amount) for new learning materials to class teacher (refer to Book List 2023)|None|None|For caregiver’s attention and action|None|None|None|
# |Friday, 20 January|None|None|Chinese New Year Celebration|None|None||School Reporting and Dismissal|None||
# |None|None|None|None|None|None|None|Time as per normal|None|None|
# |None|None|None|None|None|None|None||None|None|
# |None|None|None|None|None|None|None|Students are encouraged to to|None|None|
# |None|None|None|None|None|None|None|dress in red or in traditional|None|None|
# |None|None|None|None|None|None|None|Chinese New Year attire (e.g.|None|None|
# |None|None|None|None|None|None|None|Cheongsam / Tang suit)|None|None|
# |None|None|None|None|None|None|None||None|None|
# |23 – 24 January|None|None|Public Holiday – Chinese New Year|None|None|NO School for ALL students|NO School for ALL students|None|None|
# |Friday, 27 January|None|None|CCA Try-outs during school hours|None|None|• Pri 4 and Love 12 students • New students in MID Programme (aged 10 – 12)|• Pri 4 and Love 12 students|None||
# |None|None|None|None|None|None|None|• New students in MID|None|None|
# |None|None|None|None|None|None|None|Programme (aged 10 – 12)|None|None|
# |None|None|None|None|None|None|None|None||None|
# |Wednesday, 1 February|None|None|Prefects Investiture|None|None|12.45pm – 1.15pm|12.45pm – 1.15pm|None|None|
# |Friday, 3 February|None|None|Parent Teacher Conference 1 (PTC 1) Home-Based Learning (HBL)|None|None|NO School for ALL students|None|None|None|
# |Friday, 10 February|None|None|Commencement of CCAs (Including Swimming sessions for Pri 3, Love 4 & 5)|None|None||Duration: 3.00pm – 5.00pm|None||
# |None|None|None|None|None|None|None||None|None|
# |None|None|None|None|None|None|None|The teachers-in-charge will|None|None|
# |None|None|None|None|None|None|None|inform parents with more details.|None|None|
# |None|None|None|None|None|None|None||None|None|2023 TERM 1 SCHOOL CALENDAR  DATE Monday, 9 January |For caregiver’s attention and|
# |action|Friday, 20 January   Chinese New Year Celebration  School Reporting and Dismissal Time as per normal |Friday,|
# |27 January|• Pri 4 and Love 12 students  • New students in MID Friday, 27 January CCA Try-outs during school hours |Wednesday,|
# |1 February|Wednesday,  1 February Prefects Investiture 12.45pm – 1.15pm |Friday,|
# |3 February|Friday, 3 February Parent Teacher Conference 1 (PTC 1) Home-Based Learning (HBL) NO School for ALL students |Friday,|
# |10 February|The teachers-in-charge will inform parents with more details. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-6 T: 6561 9128
# (Pri)_Jan_2023 Term 1 Letter to Parents_signed.pdf
# [['REF: ', 11, False], ['2023/PRI/01/01 ', 11, False], [' ', 11, False], ['6 ', 11, False], ['January ', 11, False], ['2023 ', 11, False], ['Dear ', 11, False], ['Parents/Guardians, ', 11, False], ['Welcome ', 11, False], ['to ', 11, False], ['the ', 11, False], ['start ', 11, False], ['of ', 11, False], ['another ', 11, False], ['new ', 11, False], ['school ', 11, False], ['year! ', 11, False], [' ', 11, False], ['2023 ', 11, False], ['looks ', 11, False], ['to ', 11, False], ['be ', 11, False], ['an ', 11, False], ['exciting ', 11, False], ['one ', 11, False], ['as ', 11, False], ['we ', 11, False], ['resume ', 11, False], ['many ', 11, False], ['programmes ', 11, False], ['and ', 11, False], ['activities ', 11, False], ['that ', 11, False], ['had ', 11, False], ['to ', 11, False], ['be ', 11, False], ['halted ', 11, False], ['or ', 11, False], ['modified ', 11, False], ['due ', 11, False], ['to ', 11, False], ['COVID. ', 11, False], ['There ', 11, False], ['are ', 11, False], ['a ', 11, False], ['few ', 11, False], ['initiatives ', 11, False], ['we ', 11, False], ['have ', 11, False], ['been ', 11, False], ['strengthening ', 11, False], ['and ', 11, False], ['working ', 11, False], ['on ', 11, False], ['as ', 11, False], ['we ', 11, False], ['move ', 11, False], ['towards ', 11, False], ['our ', 11, False], ['vision ', 11, False], ['of ', 11, False], ['‘A ', 11, False], ['Vibrant ', 11, False], ['School ', 11, False], ['Community ', 11, False], ['where ', 11, False], ['Education ', 11, False], ['is ', 11, False], ['Transformed’. ', 11, False], ['I ', 11, False], ['look ', 11, False], ['forward ', 11, False], ['to ', 11, False], ['sharing ', 11, False], ['these ', 11, False], ['with ', 11, False], ['you ', 11, False], ['at ', 11, False], ['our ', 11, False], ['first ', 11, False], ['Parent-Teacher ', 11, False], ['Conference ', 11, False], ['on ', 11, False], ['3rd ', 11, False], ['February. ', 11, False], [' ', 11, False], [' ', 11, False], ['As ', 11, False], ['per ', 11, False], ['previous ', 11, False], ['years, ', 11, False], ['this ', 11, False], ['monthly ', 11, False], ['letter ', 11, False], ['contains ', 11, False], ['pertinent ', 11, False], ['information ', 11, False], ['that ', 11, False], ['we ', 11, False], ['hope ', 11, False], ['will ', 11, False], ['be ', 11, False], ['useful ', 11, False], ['in ', 11, False], ['navigating ', 11, False], ['the ', 11, False], ['school ', 11, False], ['year. ', 11, False], ['I ', 11, False], ['encourage ', 11, False], ['you ', 11, False], ['to ', 11, False], ['take ', 11, False], ['the ', 11, False], ['time ', 11, False], ['to ', 11, False], ['read ', 11, False], ['through ', 11, False], ['the ', 11, False], ['information ', 11, False], ['provided ', 11, False], ['in ', 11, False], ['these ', 11, False], ['letters. ', 11, False], [' ', 11, False], ['My ', 11, False], ['staff ', 11, False], ['and ', 11, False], ['I ', 11, False], ['look ', 11, False], ['forward ', 11, False], ['to ', 11, False], ['your ', 11, False], ['continued ', 11, False], ['partnership ', 11, False], ['in ', 11, False], ['our ', 11, False], ['desire ', 11, False], ['to ', 11, False], ['have ', 11, False], ['our ', 11, False], ['students ', 11, False], ['‘rooted ', 11, False], ['in ', 11, False], ['values, ', 11, False], ['prepared ', 11, False], ['for ', 11, False], ['life, ', 11, False], ['and ', 11, False], ['empowered ', 11, False], ['to ', 11, False], ['make ', 11, False], ['a ', 11, False], ['difference’. ', 11, False], [' ', 11, False], ['FOR ', 11, True], ['YOUR ', 11, True], ['ACTION ', 11, True], ['1) ', 11, False], ['Sale ', 11, True], ['of ', 11, True], ['Uniform ', 11, True], ['in ', 11, True], ['School ', 11, True], ['The ', 11, False], ['school ', 11, False], ['uniform ', 11, False], ['supplier ', 11, False], ['(Jeep ', 11, False], ['Sing ', 11, False], ['Fashion) ', 11, False], ['will ', 11, False], ['be ', 11, False], ['selling ', 11, False], ['the ', 11, False], ['school ', 11, False], [' ...
# ||Date|||Monday, 9 January 2023||
# ||Time|||10.30 a.m. – 12.15 p.m. & 12.45 p.m. – 1.30 p.m.||
# ||Venue|||In front of the school bookshop||
# |Note|Note|None||When out-of-stock occurs, the uniform vendor will contact parents directly for collection when||
# |None|None|None|None|the stock arrives. The School will not issue the uniforms to your child, including students on the|None|
# |None|None|None|None|Financial Assistance Scheme.|None|REF: 2023/PRI/01/01  6 January 2023 Dear Parents/Guardians, Welcome to the start of another new school year!  2023 looks to be an exciting one as we resume many programmes and activities that had to be halted or modified due to COVID. There are a few initiatives we have been strengthening and working on as we move towards our vision of ‘A Vibrant School Community where Education is Transformed’. I look forward to sharing these with you at our first Parent-Teacher Conference on 3rd February.   As per previous years, this monthly letter contains pertinent information that we hope will be useful in navigating the school year. I encourage you to take the time to read through the information provided in these letters.  My staff and I look forward to your continued partnership in our desire to have our students ‘rooted in values, prepared for life, and empowered to make a difference’.  FOR YOUR ACTION 1) Sale of Uniform in School The school uniform supplier (Jeep Sing Fashion) will be selling the school uniform in front of the school bookshop: Date  Time Venue Note When out-of-stock occurs, the uniform vendor will contact parents directly for collection when the stock arrives. The School will not issue the uniforms to your child, including students on the Financial Assistance Scheme. Monday, 9 January 2023 10.30 a.m. – 12.15 p.m. & 12.45 p.m. – 1.30 p.m. In front of the school bookshop As part of school safety and security, caregivers entering the school will need to register with the security officer at the school main entrance.  2) Temperature-Taking Exercise The school will be conducting a temperature-taking exercise on Wednesday, 11 January 2023, as part of the Safe Management Measures. All students MUST bring their digital thermometer to school on that day. Students may purchase the digital thermometer at $3.50 and/or a battery at $0.20 at the General Office/school bookshop.  3) 2023 Book List  The 2023 Book List will be issued on Monday, 9 Jaunuary. The class teacher will indicate on the list the required learning materials to be purchased for your child/ward. Please pay the exact amount for the materials to your child/ward’s class teacher by Friday, 13 January. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-1 T: 6561 9128     4) School Fees Schedule 2023 The 1st quarter school fees (Jan to March) will be scheduled between 13 and 17 March 2023. You are strongly encouraged to pay your child’s school fees via GIRO/Edusave (please note that a portion of the school fees of $6.50 cannot be deducted from Edusave and will have to be paid via GIRO or in cash). For parents/guardians who have NOT opted for GIRO deduction or whose applications are unsuccessful, school fees are to be paid to the General Office via cash/cheque (payable to Grace Orchard School A/C 2).  Please refer to the Student Diary page 15 on the school fees schedule and amount for the respective programme. In the event that a student withdraws from school before the month, school fees for the month must still be paid in full.  UPCOMING SCHOOL PROGRAMME / ACTIVITIES 5) 20 January, Friday – Chinese New Year Celebration The school will be celebrating Chinese New Year on Friday, 20 January 2023. As part of the celebrations, we encourage all students to dress in red or in traditional Chinese New Year attire (e.g. Cheongsam / Tang Suit). As it is not the eve of Chinese New Year, there will be NO changes to the school reporting and dismissal time on that day. 6) 1 February, Wednesday – Prefects' Investiture   The Prefects’ Investiture will be held on 1 February, 1.00 p.m. – 1.30 p.m.  The investiture is the platform to recognise our prefects for their contribution and dedication in serving the school and community. Parents of the prefects will be invited to witness the ceremony. 7) 3 February, Friday – Parent-Teacher Conference 1 (HBL ...
# ||School Mainline||+65 6561 9128|
# |WhatsApp / SMS|WhatsApp / SMS|None|Please note that the teachers are not obligated to give parents their contact number. If given, it would be a mutual arrangement between parents and teachers. For emergency matters during curriculum time, please contact the School's mainline as the teachers are having lessons and may not be able to respond promptly.|9) Communication with Teachers Parents may communicate with teachers via the following ways: ||Session|||Reporting Time|||Dismissal Time||
# |PM Session|None|None|12.15 pm|None|None|5.30 pm|None|None|
# ||Daily Dismissal Procedures|None|None|None|None|None|None||
# |By School Bus|None|None|• Students taking school transport will be dismissed at the bus bay at 5.30 p.m.|None|None|None|None|None|
# |By Car|None|None|• Parents can drive in and fetch their children at the bus bay from 5.30 p.m. [after the last school bus has left the school carpark] • No cars are allowed to park or wait in the school car park before the dismissal hours.|None|None|None|None|None|
# |By Caregivers / Independent Travellers|None|None|• Students who are fetched by parents or are independent travellers will be dismissed at 5.30 p.m. Caregivers are to wait for their children at the covered walkway next to Side Gate C.|None|None|None|None|None|The School will close at 6.30 p.m. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-3 T: 6561 9128     |CCAs are during curriculum hours and the programmes will commence on T1W6.|
# |Modular CCAs|12) School Safety and Security  The security of the school is crucial in providing a safe environment for the education of our students. We seek your understanding and cooperation in complying with the Road Safety and Visitor Management Policies. A. No Parking in the School Carpark i. Only the school staff and visitors with scheduled appointments can park in the school carpark. ii. Drive-in is allowed during the school arrival and dismissal time for drop-off and pick-up only. The engine of all parked vehicles must be turned off according to the Environmental Protection and Management (vehicular-emissions) Regulations. Failure to comply may lead to a report to the NEA for further actions. |Modular CCA|Venue|Objectives|Classes Involved|
# |Swimming|Clementi Swimming Complex|To provide students with the knowledge and skills for water safety as well as basic swimming competencies|Primary 3 Classes Love 4 and Love 5 (Semester 1 only)|
# |Gym|In School|To enhance the physical development of the students, developing skills such as strength, flexibility, coordination, balance, and body control|Junior Classes Love 6 – 11|CCA Try-outs  Upper Primary and Love 12 students will be placed in a CCA based on their strengths and interest. Students who do not have a CCA will take part in a CCA try-out on Friday, 27 January. |None|enhance the physical development of the|
# |students, developing skills such as strength,|None|
# |flexibility, coordination, balance, and body|None|
# |control|None|14) Health and Fitness Programme The objective of the school’s Health and Fitness programme is to help students to build healthy habits and exercise regularly. To aid your child in this programme, a Health and Fitness booklet will be distributed each semester.  In line with our school’s SWPBS system, students will get to earn hero chops by showing responsibility for their own health and completing the exercises. Do encourage your child/ward to do the exercises daily. |Upper Primary and Love 12 students will be placed in a CCA based on their strengths and interest. Students|
# |who do not have a CCA will take part in a CCA try-out on Friday, 27 January.|
# ||Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-4 T: 6561 9128     |Name of Insurer|None|Chubb Insurance Singapore Limited|None|
# |Medical expenses limit|None|$7,500 per student (Note: Medical expenses limit for registered Chinese physician – $150 per student)|None|
# |Accident death & permanent disablement benefits|None|$25,000 per student|None|
# ||20% co-payment requirement for parents on each medical expenses claim submitted (i.e. the insurer|None||
# |None|will reimburse only up to 80% of all approved medical expenses incurred.)|None|None|15) Student Group Personal Accident Insurance Policy ours Sincerely,
#
# oi
#
# fs Esther Kwan
# rincipal
#
#
# All students of Grace Orchard School are covered under the Student Group Personal Accident Insurance Policy. The insurance can help parents cover some medical expenses that may be incurred if their children are injured while participating in school activities.  Listed below are the revised benefits and terms in the Student Group Personal Accident Insurance Policy currently in force – for your necessary attention: |$7,500 per student (Note: Medical expenses limit for|
# |registered Chinese physician – $150 per student)|$7,500 per student (Note: Medical expenses limit for registered Chinese physician – $150 per student) Medical expenses limit $25,000 per student Accident death & permanent disablement benefits 20% co-payment requirement for parents on each medical expenses claim submitted (i.e. the insurer will reimburse only up to 80% of all approved medical expenses incurred.) The medical expenses claim form is available from the General Office. The claim form with the original medical receipts must be submitted to School within 14 days from the date of the accident. If you have any further query about the above insurance policy, please contact the school Admin Executive at 6561 9128 ext.108 or info@go.edu.sg (via email). Yours Sincerely, Ms Esther Kwan Principal Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-5 T: 6561 9128     ||DATE|||EVENT / ACTIVITY|||REMARKS|None||
# |Monday, 9 January|None|None|Sale of School Uniform|Sale of School Uniform|None|10.30 am – 12.15 pm & 12.45 pm – 1.30 pm|None|None|None|
# |Friday, 13 January|None|None|Payment (exact amount) for new learning materials to class teacher (refer to Book List 2023)|None|None|For caregiver’s attention and action|None|None|None|
# |Friday, 20 January|None|None|Chinese New Year Celebration|None|None||School Reporting and Dismissal|None||
# |None|None|None|None|None|None|None|Time as per normal|None|None|
# |None|None|None|None|None|None|None||None|None|
# |None|None|None|None|None|None|None|Students are encouraged to to|None|None|
# |None|None|None|None|None|None|None|dress in red or in traditional|None|None|
# |None|None|None|None|None|None|None|Chinese New Year attire (e.g.|None|None|
# |None|None|None|None|None|None|None|Cheongsam / Tang suit)|None|None|
# |None|None|None|None|None|None|None||None|None|
# |23 – 24 January|None|None|Public Holiday – Chinese New Year|None|None|NO School for ALL students|NO School for ALL students|None|None|
# |Friday, 27 January|None|None|CCA Try-outs during school hours|None|None|• Pri 4 and Love 12 students • New students in MID Programme (aged 10 – 12)|• Pri 4 and Love 12 students|None||
# |None|None|None|None|None|None|None|• New students in MID|None|None|
# |None|None|None|None|None|None|None|Programme (aged 10 – 12)|None|None|
# |None|None|None|None|None|None|None|None||None|
# |Wednesday, 1 February|None|None|Prefects Investiture|None|None|12.45pm – 1.15pm|12.45pm – 1.15pm|None|None|
# |Friday, 3 February|None|None|Parent Teacher Conference 1 (PTC 1) Home-Based Learning (HBL)|None|None|NO School for ALL students|None|None|None|
# |Friday, 10 February|None|None|Commencement of CCAs (Including Swimming sessions for Pri 3, Love 4 & 5)|None|None||Duration: 3.00pm – 5.00pm|None||
# |None|None|None|None|None|None|None||None|None|
# |None|None|None|None|None|None|None|The teachers-in-charge will|None|None|
# |None|None|None|None|None|None|None|inform parents with more details.|None|None|
# |None|None|None|None|None|None|None||None|None|2023 TERM 1 SCHOOL CALENDAR  DATE Monday, 9 January |For caregiver’s attention and|
# |action|Friday, 20 January   Chinese New Year Celebration  School Reporting and Dismissal Time as per normal |Friday,|
# |27 January|• Pri 4 and Love 12 students  • New students in MID Friday, 27 January CCA Try-outs during school hours |Wednesday,|
# |1 February|Wednesday,  1 February Prefects Investiture 12.45pm – 1.15pm |Friday,|
# |3 February|Friday, 3 February Parent Teacher Conference 1 (PTC 1) Home-Based Learning (HBL) NO School for ALL students |Friday,|
# |10 February|The teachers-in-charge will inform parents with more details. Grace Orchard School 恩园学校 Shaping Special Lives for Significance 170 West Coast Road, Singapore 127443. www.go.edu.sg  F: 6561 4133 PRI-6 T: 6561 9128
# (Pri)_Jan_2023 Term 1 Letter to Parents_signed.pdf

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 100)
# words_df
words_df.head(10)
# Out:
#                   word  font_size   bold
# 0                REF:          11  False
# 1      2023/PRI/01/01          11  False
# 2                              11  False
# 3                   6          11  False
# 4             January          11  False
# 5                2023          11  False
# 6                Dear          11  False
# 7  Parents/Guardians,          11  False
# 8             Welcome          11  False
# 9                  to          11  False

# %%
import numpy as np
words_df = words_df.replace(' ', np.nan).dropna().reset_index(drop=True)
words_df
words_df.head(10)
# Out:
#                   word  font_size   bold
# 0                REF:          11  False
# 1      2023/PRI/01/01          11  False
# 2                   6          11  False
# 3             January          11  False
# 4                2023          11  False
# 5                Dear          11  False
# 6  Parents/Guardians,          11  False
# 7             Welcome          11  False
# 8                  to          11  False
# 9                 the          11  False

# %%
words_df['font_size'] = words_df.apply(lambda x: x['font_size'] * 2 if x['bold'] else x['font_size'], axis=1)
words_df = words_df.reset_index().rename(columns={'index': 'seq_no'})
words_df.head(100)
# Out:
#     seq_no                 word  font_size   bold
# 0        0                REF:          11  False
# 1        1      2023/PRI/01/01          11  False
# 2        2                   6          11  False
# 3        3             January          11  False
# 4        4                2023          11  False
# 5        5                Dear          11  False
# 6        6  Parents/Guardians,          11  False
# 7        7             Welcome          11  False
# 8        8                  to          11  False
# 9        9                 the          11  False
# 10      10               start          11  False
# 11      11                  of          11  False
# 12      12             another          11  False
# 13      13                 new          11  False
# 14      14              school          11  False
# 15      15               year!          11  False
# 16      16                2023          11  False
# 17      17               looks          11  False
# 18      18                  to          11  False
# 19      19                  be          11  False
# 20      20                  an          11  False
# 21      21            exciting          11  False
# 22      22                 one          11  False
# 23      23                  as          11  False
# 24      24                  we          11  False
# 25      25              resume          11  False
# 26      26                many          11  False
# 27      27          programmes          11  False
# 28      28                 and          11  False
# 29      29          activities          11  False
# 30      30                that          11  False
# 31      31                 had          11  False
# 32      32                  to          11  False
# 33      33                  be          11  False
# 34      34              halted          11  False
# 35      35                  or          11  False
# 36      36            modified          11  False
# 37      37                 due          11  False
# 38      38                  to          11  False
# 39      39              COVID.          11  False
# 40      40               There          11  False
# 41      41                 are          11  False
# 42      42                   a          11  False
# 43      43                 few          11  False
# 44      44         initiatives          11  False
# 45      45                  we          11  False
# 46      46                have          11  False
# 47      47                been          11  False
# 48      48       strengthening          11  False
# 49      49                 and          11  False
# 50      50             working          11  False
# 51      51                  on          11  False
# 52      52                  as          11  False
# 53      53                  we          11  False
# 54      54                move          11  False
# 55      55             towards          11  False
# 56      56                 our          11  False
# 57      57              vision          11  False
# 58      58                  of          11  False
# 59      59                  ‘A          11  False
# 60      60             Vibrant          11  False
# 61      61              School          11  False
# 62      62           Community          11  False
# 63      63               where          11  False
# 64      64           Education          11  False
# 65      65                  is          11  False
# 66      66       Transformed’.          11  False
# 67      67                   I          11  False
# 68      68                look          11  False
# 69      69             forward          11  False
# 70      70                  to          11  False
# 71      71             sharing          11  False
# 72      72               these          11  False
# 73      73                with          11  False
# 74      74                 you          11  False
# 75      75                  at          11  False
# 76      76                 our          11  False
# 77      77               first          11  False
# 78      78      Parent-Teacher          11  False
# 79      79          Conference          11  False
# 80      80                  on          11  False
# 81      81                 3rd          11  False
# 82      82           February.          11  False
# 83      83                  As          11  False
# 84      84                 per          11  False
# 85      85            previous          11  False
# 86      86              years,          11  False
# 87      87                this          11  False
# 88      88             monthly          11  False
# 89      89              letter          11  False
# 90      90            contains          11  False
# 91      91           pertinent          11  False
# 92      92         information          11  False
# 93      93                that          11  False
# 94      94                  we          11  False
# 95      95                hope          11  False
# 96      96                will          11  False
# 97      97                  be          11  False
# 98      98              useful          11  False
# 99      99                  in          11  False

# %%
mode_font_size = words_df['font_size'].mode()[0]
mode_font_size
# Out:
# 11

# %%
words_df['font_size'].nsmallest(5)
# Out:
# 362    8
# 363    8
# 366    8
# 367    8
# 368    8
# Name: font_size, dtype: int64

# %%
words_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507 entries, 0 to 1506
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   seq_no     1507 non-null   int64
#  1   word       1507 non-null   object
#  2   font_size  1507 non-null   int64
#  3   bold       1507 non-null   bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 36.9+ KB

# %%
# Group by font size and count the occurrences
font_size_group = words_df.groupby('font_size').size().reset_index(name='counts')

# Calculate the proportion of each font size
total_words = font_size_group['counts'].sum()
font_size_group['proportion'] = (font_size_group['counts'] / total_words) * 100

# Sort by counts to get the less common font sizes
font_size_group_sorted = font_size_group.sort_values(by='font_size', ascending=False)

font_size_group_sorted['cumulative_proportion'] = font_size_group_sorted['proportion'].cumsum()

font_size_group_sorted
# Out:
#    font_size  counts  proportion  cumulative_proportion
# 4         22     136    9.024552               9.024552
# 3         16      12    0.796284               9.820836
# 2         11    1239   82.216324              92.037160
# 1         10      12    0.796284              92.833444
# 0          8     108    7.166556             100.000000

# %%
# Define a threshold for the maximum proportion you consider significant
threshold = 20  # This means we consider font sizes that constitute less than 5% of the document

# Filter the DataFrame to get font sizes whose cumulative proportion is under the threshold
significant_font_sizes = font_size_group_sorted[font_size_group_sorted['cumulative_proportion'] <= threshold]

significant_font_sizes
# Out:
#    font_size  counts  proportion  cumulative_proportion
# 4         22     136    9.024552               9.024552
# 3         16      12    0.796284               9.820836

# %%
keywords_df = pd.DataFrame()

keywords = False

if not significant_font_sizes.empty:
    keywords = True
    # Extract the list of significant font sizes
    significant_sizes = significant_font_sizes['font_size'].tolist()

    # Filter the original DataFrame to only include rows with significant font sizes
    keywords_df = words_df[words_df['font_size'].isin(significant_sizes)]

keywords_df
# Out:
#       seq_no                 word  font_size  bold
# 149      149                 FOR          22  True
# 150      150                YOUR          22  True
# 151      151              ACTION          22  True
# 153      153                Sale          22  True
# 154      154                  of          22  True
# 155      155             Uniform          22  True
# 156      156                  in          22  True
# 157      157              School          22  True
# 177      177                Date          22  True
# 178      178                Time          22  True
# 179      179               Venue          22  True
# 180      180                Note          22  True
# 214      214             Monday,          22  True
# 215      215                   9          22  True
# 216      216             January          22  True
# 217      217                2023          22  True
# 260      260  Temperature-Taking          22  True
# 261      261            Exercise          22  True
# 271      271          Wednesday,          22  True
# 272      272                  11          22  True
# 273      273             January          22  True
# 274      274               2023,          22  True
# 284      284                MUST          22  True
# 313      313                2023          22  True
# 314      314                Book          22  True
# 315      315                List          22  True
# 359      359             Friday,          22  True
# 360      360                  13          22  True
# 361      361            January.          22  True
# 365      365                恩园学校          16  True
# 376      376             127443.          16  True
# 386      386              School          22  True
# 387      387                Fees          22  True
# 388      388            Schedule          22  True
# 389      389                2023          22  True
# 401      401             between          22  True
# 402      402                  13          22  True
# 403      403                 and          22  True
# 404      404                  17          22  True
# 405      405               March          22  True
# 406      406               2023.          22  True
# 450      450                 NOT          22  True
# 521      521            UPCOMING          22  True
# 522      522              SCHOOL          22  True
# 523      523           PROGRAMME          22  True
# 524      524                   /          22  True
# 525      525          ACTIVITIES          22  True
# 527      527                  20          22  True
# 528      528            January,          22  True
# 529      529              Friday          22  True
# 530      530                   –          22  True
# 531      531             Chinese          22  True
# 532      532                 New          22  True
# 533      533                Year          22  True
# 534      534         Celebration          22  True
# 599      599                   1          22  True
# 600      600           February,          22  True
# 601      601           Wednesday          22  True
# 602      602                   –          22  True
# 603      603           Prefects'          22  True
# 604      604         Investiture          22  True
# 651      651                   3          22  True
# 652      652           February,          22  True
# 653      653              Friday          22  True
# 654      654                   –          22  True
# 655      655      Parent-Teacher          22  True
# 656      656          Conference          22  True
# 657      657                   1          22  True
# 658      658                (HBL          22  True
# 659      659                 for          22  True
# 660      660                 all          22  True
# 661      661           students)          22  True
# 810      810           IMPORTANT          22  True
# 811      811              SCHOOL          22  True
# 812      812         INFORMATION          22  True
# 814      814             Student          22  True
# 815      815                Care          22  True
# 816      816              Centre          22  True
# 817      817                   @          22  True
# 818      818               Grace          22  True
# 819      819             Orchard          22  True
# 820      820              School          22  True
# 886      886                恩园学校          16  True
# 897      897             127443.          16  True
# 907      907       Communication          22  True
# 908      908                with          22  True
# 909      909            Teachers          22  True
# 919      919                 The          22  True
# 920      920              School          22  True
# 921      921                will          22  True
# 922      922               close          22  True
# 923      923                  at          22  True
# 924      924                6.30          22  True
# 925      925                p.m.          22  True
# 929      929                恩园学校          16  True
# 940      940             127443.          16  True
# 950      950              School          22  True
# 951      951              Safety          22  True
# 952      952                 and          22  True
# 953      953            Security          22  True
# 988      988                  A.          22  True
# 989      989                  No          22  True
# 990      990             Parking          22  True
# 991      991                  in          22  True
# 992      992                 the          22  True
# 993      993              School          22  True
# 994      994             Carpark          22  True
# 1099    1099              Health          22  True
# 1100    1100                 and          22  True
# 1101    1101             Fitness          22  True
# 1102    1102           Programme          22  True
# 1177    1177                恩园学校          16  True
# 1188    1188             127443.          16  True
# 1198    1198             Student          22  True
# 1199    1199               Group          22  True
# 1200    1200            Personal          22  True
# 1201    1201            Accident          22  True
# 1202    1202           Insurance          22  True
# 1203    1203              Policy          22  True
# 1282    1282             Medical          22  True
# 1283    1283            expenses          22  True
# 1284    1284               limit          22  True
# 1288    1288            Accident          22  True
# 1289    1289               death          22  True
# 1290    1290                   &          22  True
# 1291    1291           permanent          22  True
# 1292    1292         disablement          22  True
# 1293    1293            benefits          22  True
# 1294    1294                 20%          22  True
# 1295    1295          co-payment          22  True
# 1296    1296         requirement          22  True
# 1297    1297                 for          22  True
# 1298    1298             parents          22  True
# 1387    1387                恩园学校          16  True
# 1398    1398             127443.          16  True
# 1407    1407                2023          22  True
# 1408    1408                TERM          22  True
# 1409    1409                   1          22  True
# 1410    1410              SCHOOL          22  True
# 1411    1411            CALENDAR          22  True
# 1412    1412                DATE          22  True
# 1471    1471                  NO          22  True
# 1472    1472              School          22  True
# 1473    1473                 for          22  True
# 1474    1474                 ALL          22  True
# 1475    1475            students          22  True
# 1487    1487                恩园学校          16  True
# 1498    1498             127443.          16  True

# %%
# Initialize variables
# grouped_phrases = []
keywords = []
current_phrase = ''
previous_seq_no = -1

# Iterate through the DataFrame rows
for index, row in keywords_df.iterrows():
    keywords.append(row['word'].strip())
#     # Check if the current seq_no is consecutive to the previous one
#     if row['seq_no'] == previous_seq_no + 1:
#         # If consecutive, add the word to the current phrase
#         current_phrase += ('' + row['word'])
#     else:
#         # If not consecutive, and the current phrase is not empty,
#         # add the current phrase to the list of grouped phrases
#         if current_phrase:
#             grouped_phrases.append(current_phrase.strip())
#         # Start a new phrase with the current word
#         current_phrase = row['word']
#     # Update the previous seq_no to the current one
#     previous_seq_no = row['seq_no']

# # Add the last phrase to the list if not empty
# if current_phrase:
#     grouped_phrases.append(current_phrase.strip())

# # Resulting array of grouped phrases
# grouped_phrases_array = np.array(grouped_phrases)
# print(grouped_phrases_array)

final_keywords = ' '.join(keywords)
final_keywords
# Out:
# "FOR YOUR ACTION Sale of Uniform in School Date Time Venue Note Monday, 9 January 2023 Temperature-Taking Exercise Wednesday, 11 January 2023, MUST 2023 Book List Friday, 13 January. 恩园学校 127443. School Fees Schedule 2023 between 13 and 17 March 2023. NOT UPCOMING SCHOOL PROGRAMME / ACTIVITIES 20 January, Friday – Chinese New Year Celebration 1 February, Wednesday – Prefects' Investiture 3 February, Friday – Parent-Teacher Conference 1 (HBL for all students) IMPORTANT SCHOOL INFORMATION Student Care Centre @ Grace Orchard School 恩园学校 127443. Communication with Teachers The School will close at 6.30 p.m. 恩园学校 127443. School Safety and Security A. No Parking in the School Carpark Health and Fitness Programme 恩园学校 127443. Student Group Personal Accident Insurance Policy Medical expenses limit Accident death & permanent disablement benefits 20% co-payment requirement for parents 恩园学校 127443. 2023 TERM 1 SCHOOL CALENDAR DATE NO School for ALL students 恩园学校 127443."

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(str(final_keywords))

filtered_tokens = set(token.text.lower() for token in doc if not token.is_stop and 
                                                              not token.like_num and 
                                                              token.is_alpha and 
                                                              token.ent_type_ not in ['DATE', 'TIME'])


filtered_text = " ".join(filtered_tokens)

doc = nlp(filtered_text)

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{10}} {token.ent_type_:{10}}')
# Out:
# grace      NOUN
# date       NOUN
# co         NOUN
# expenses   NOUN
# student    NOUN
# payment    NOUN
# celebration NOUN
# schedule   NOUN
# february   PROPN      DATE
# time       NOUN
# conference NOUN
# information NOUN
# exercise   NOUN
# upcoming   ADJ
# orchard    NOUN
# health     NOUN
# fitness    NOUN
# venue      NOUN
# parking    NOUN
# benefits   NOUN
# permanent  ADJ
# medical    ADJ
# teachers   NOUN
# uniform    PROPN
# book       PROPN
# centre     PROPN
# group      NOUN
# temperature NOUN
# death      NOUN
# security   NOUN
# accident   NOUN
# investiture ADJ
# important  ADJ
# requirement NOUN
# close      ADJ
# policy     NOUN
# communication NOUN
# carpark    NOUN
# personal   ADJ
# list       NOUN
# fees       NOUN
# sale       VERB
# chinese    ADJ        NORP
# students   NOUN
# term       PROPN
# school     NOUN
# disablement NOUN
# programme  NOUN
# hbl        PROPN
# action     NOUN
# teacher    NOUN
# insurance  NOUN
# parent     NOUN
# year       NOUN
# new        ADJ
# 恩园学校       ADJ
# prefects   NOUN
# activities NOUN
# safety     NOUN
# care       NOUN
# note       NOUN
# parents    NOUN
# taking     VERB
# limit      NOUN
# calendar   NOUN
